# %% [markdown]
# ## 단어 벡터화와 임베딩
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 임베딩 : 다차원에 단어를 심는다
#   - 차원에서의 단어간의 관계, 거리 등을 파악
#
# - <a href="http://projector.tensorflow.org/?hl=ko">임베딩 프로젝터</a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 숫자가 낮을 수록 빈도수가 높은 것(빈도수대로 정렬해주기 때문임)
# - 0 : 패딩, 1 : unknown
